# %% [markdown]
# ## 1. Connect to IB

# %%
from STOCKBOT import StockBot
bot = StockBot()
bot.connect_to_ib()

# %% [markdown]
# ## 2. Scan Market and Sectors

# %%
bot.ma.set_sectors()  
bot.ma.create_analysis_report()
display(bot.ma.market_report_df)
display(bot.ma.sector_report_df)
display(bot.ma.filter_sectors(as_list_of_sectors=False, min_momentum=-3, sort_by='Overall Score', min_score=5))
print(bot.ma.sector_report_filtered_list)
# Out:
# Running market and sector analysis first...
#                         Metric  \
# 0            SPY Current Price
# 1                SPY 20-Day MA
# 2                SPY 50-Day MA
# 3               SPY 200-Day MA
# 4                     SPY VWAP
# 5            Price vs 20MA (%)
# 6            Price vs 50MA (%)
# 7           Price vs 200MA (%)
# 8            Price vs VWAP (%)
# 9                      SPY RSI
# 10            SPY ROC (10-day)
# 11                   RSI Trend
# 12                   ROC Trend
# 13              Current Volume
# 14           20-Day Avg Volume
# 15  Volume Ratio (Current/Avg)
# 16                Volume Trend
# 17            Short-term Trend
# 18           Medium-term Trend
# 19             Long-term Trend
# 20              Trend Strength
# 21            Market Condition
# 22           Market Return (%)
#
#                                                             Description  \
# 0                                       Current market price of SPY ETF
# 1             20-day simple moving average - short-term trend indicator
# 2            50-day simple moving average - medium-term trend indicator
# 3             200-day simple moving average - long-term trend indicator
# 4   Volume Weighted Average Price - shows average price based on volume
# 5             Percentage difference between current price and 20-day MA
# 6             Percentage difference between current price and 50-day MA
# 7            Percentage difference between current price and 200-day MA
# 8                  Percentage difference between current price and VWAP
# 9         Relative Strength Index (14-day) - momentum indicator (0-100)
# 10                   Rate of Change over 10 days - momentum measurement
# 11                    RSI interpretation (Overbought >70, Oversold <30)
# 12                         Direction of price change over 10-day period
# 13                                               Today's trading volume
# 14                   Average daily volume over the last 20 trading days
# 15                     Ratio of current volume to 20-day average volume
# 16                                  Volume comparison to 20-day average
# 17                                  Trend based on 20-day MA comparison
# 18                                  Trend based on 50-day MA comparison
# 19                                 Trend based on 200-day MA comparison
# 20                     Number of bullish trends out of three timeframes
# 21                            Overall market assessment based on trends
# 22                                   Market return over analysis period
#
#             Value                                Interpretation
# 0          584.64                    Current market price point
# 1          598.58        Price above 20MA is bullish short-term
# 2          592.84       Price above 50MA is bullish medium-term
# 3          554.08        Price above 200MA is bullish long-term
# 4          532.17    Price above VWAP indicates buying pressure
# 5           -2.33   Positive % indicates price strength vs 20MA
# 6           -1.38   Positive % indicates price strength vs 50MA
# 7            5.52  Positive % indicates price strength vs 200MA
# 8            9.86  Positive % indicates current buying pressure
# 9           30.48            RSI > 70 overbought, < 30 oversold
# 10          -3.25      Positive values indicate upward momentum
# 11        Neutral              Current RSI trend interpretation
# 12       Negative         Current price momentum interpretation
# 13         329555                Today's trading activity level
# 14         272000              Normal trading activity baseline
# 15           1.21          > 1.0 indicates above-average volume
# 16  Above Average                   Volume trend interpretation
# 17        Bearish                    Short-term trend direction
# 18        Bearish                   Medium-term trend direction
# 19        Bullish                     Long-term trend direction
# 20            1/3    Number of bullish trends (more = stronger)
# 21        Bearish               Overall market trend assessment
# 22          -3.79                Market performance over period
#                     Sector   ETF  Return (%)  Relative Strength  \
# 1   Communication Services   XLC       -2.95               0.84
# 2               Technology   XLK       -3.80              -0.01
# 3               Financials   XLF       -4.08              -0.29
# 0   Consumer_Discretionary   XLY       -2.10               1.69
# 5                Utilities   XLU       -5.18              -1.40
# 6                   Energy   XLE       -6.04              -2.25
# 4         Consumer_Staples   XLP       -4.96              -1.17
# 7               Healthcare   XLV       -6.22              -2.43
# 8              Industrials   XLI       -7.96              -4.17
# 9              Real_Estate  XLRE       -8.31              -4.52
# 10               Materials   XLB      -11.01              -7.22
#
#     Momentum (ROC) Volume Trend Outperforming SPY Momentum Direction  \
# 1            -3.27   Increasing               Yes           Negative
# 2            -3.34   Increasing                No           Negative
# 3            -1.81   Increasing                No           Negative
# 0            -7.53   Increasing               Yes           Negative
# 5            -0.56   Increasing                No           Negative
# 6             0.06   Increasing                No           Positive
# 4            -3.81   Increasing                No           Negative
# 7            -1.15   Increasing                No           Negative
# 8            -3.66   Increasing                No           Negative
# 9            -5.02   Increasing                No           Negative
# 10           -5.39   Increasing                No           Negative
#
#     Relative Strength Rank  Return Rank  Momentum Rank  Overall Score
# 1                        2          2.0            5.0       7.000000
# 2                        3          3.0            6.0       6.000000
# 3                        4          4.0            4.0       6.000000
# 0                        1          1.0           11.0       5.666667
# 5                        6          6.0            2.0       5.333333
# 6                        7          7.0            1.0       5.000000
# 4                        5          5.0            8.0       4.000000
# 7                        8          8.0            3.0       3.666667
# 8                        9          9.0            7.0       1.666667
# 9                       10         10.0            9.0       0.333333
# 10                      11         11.0           10.0      -0.666667
#        Sector  ETF  Return (%)  Relative Strength  Momentum (ROC)  \
# 3  Financials  XLF       -4.08              -0.29           -1.81
# 5   Utilities  XLU       -5.18              -1.40           -0.56
# 6      Energy  XLE       -6.04              -2.25            0.06
#
#   Volume Trend Outperforming SPY Momentum Direction  Relative Strength Rank  \
# 3   Increasing                No           Negative                       4
# 5   Increasing                No           Negative                       6
# 6   Increasing                No           Positive                       7
#
#    Return Rank  Momentum Rank  Overall Score
# 3          4.0            4.0       6.000000
# 5          6.0            2.0       5.333333
# 6          7.0            1.0       5.000000
# (['Financials', 'Utilities', 'Energy'], ['XLF', 'XLU', 'XLE'])

# %% [markdown]
# ## 3. Scan For Stocks

# %%
import scanner.schedule as schedule
market = schedule.MarketSchedule(scan_time='01:39', sleep_time=600) 

# if market.wait_for_scan_time():
bot.scan(
        scanCode     = "TOP_PERC_GAIN", 
        price        = (1, 100),
        volume       = 100_000, 
        changePerc   = 4, 
        marketCap    = 100, # in millions
        limitEachCap = 20
    )
    
display(bot.scanner.scan_results_df)
# Out:
# Scanning STK.US.MAJOR for TOP_PERC_GAIN ..
# price: (1, 100), volume: 100000, changePerc: 4, marketCap: (100, 1000)
# STK.US.MAJOR .. len(data): 0
# Scanning STK.US.MAJOR for TOP_PERC_GAIN ..
# price: (1, 100), volume: 100000, changePerc: 4, marketCap: (1000, 10000)
# STK.US.MAJOR .. len(data): 0
# Scanning STK.US.MAJOR for TOP_PERC_GAIN ..
# price: (1, 100), volume: 100000, changePerc: 4, marketCap: (10000, 100000)
# STK.US.MAJOR .. len(data): 0
# Error 162, reqId 245: Historical Market Data Service error message:API scanner subscription cancelled: 245
# Error 162, reqId 246: Historical Market Data Service error message:API scanner subscription cancelled: 246
# Error 162, reqId 247: Historical Market Data Service error message:API scanner subscription cancelled: 247
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 5
#       2 market = schedule.MarketSchedule(scan_time='01:39', sleep_time=600)
#       4 # if market.wait_for_scan_time():
# ----> 5 bot.scan(
#       6         scanCode     = "TOP_PERC_GAIN",
#       7         price        = (1, 100),
#       8         volume       = 100_000,
#       9         changePerc   = 4,
#      10         marketCap    = 100, # in millions
#      11         limitEachCap = 20
#      12     )
#      14 display(bot.scanner.scan_results_df)
#
# File c:\Users\sidsu\anaconda3\envs\SB4\stockbot4\STOCKBOT.py:42, in StockBot.scan(self, scanCode, price, volume, changePerc, marketCap, limitEachCap)
#      40 def scan(self, scanCode:str, price:Tuple[int, int], volume:int, changePerc:int, marketCap:int, limitEachCap:int):
#      41     # multi scan breaks the scan by market cap into smaller chunks so more than 50 stocks can be scanned
# ---> 42     self.scanner.multiscan(
#      43         scan_code=scanCode,
#      44         price=price,
#      45         volume=volume,
#      46         change_perc=changePerc,
#      47         market_cap=marketCap, # in millions
#      48         limit_each_cap=limitEachCap
#      49     )
#      51     # set up the tracker for the results
#      52     self.tracker_df = pd.DataFrame(index=self.scanner.scan_results_df.index)
#
# File c:\Users\sidsu\anaconda3\envs\SB4\stockbot4\scanner\scanner.py:88, in StockbotScanner.multiscan(self, scan_code, price, volume, change_perc, market_cap, limit_each_cap)
#      85 columns = ['Rank', 'Symbol', 'Market Cap Range' ]
#      87 # Store DataFrame in instance variable and return it
# ---> 88 self.scan_results_df = df[columns].sort_values('Rank')
#      89 return df
#
# File c:\Users\sidsu\anaconda3\envs\SB2\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\sidsu\anaconda3\envs\SB2\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\Users\sidsu\anaconda3\envs\SB2\lib\site-packages\pandas\core\indexes\base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Rank', 'Symbol', 'Market Cap Range'], dtype='object')] are in the [columns]"

# %% [markdown]
# ## 4. Get Stock Funadamentals

# %%
# allowed_etfs = bot.ma.sector_report_filtered_list[1]
from STOCKBOT import StockBot
bot = StockBot()
bot.connect_to_ib()
display(bot.tracker_df)
bot.setup_stocks(overrideScnaedStockList=['TSLA', 'ROKU', 'SOFI'])
# bot.setup_stocks()
bot.run_fundamentals(allowedETFs= ['XLF', 'XLU', 'XLV'])
bot.run_daily_frames(mustHaveAprovedETF=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Using cached data for TSLA (age: 2025-01-02 11:31:48)
# Using cached data for ROKU (age: 2025-01-03 09:10:09)
# Using cached data for SOFI (age: 2025-01-03 09:10:10)
# Symbol SOFI is not allowed
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\SPY_1_day.csv
# Stored data: 268 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\SPY_1_day.csv
# Data loaded: 268 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\XLY_1_day.csv
# Stored data: 253 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\XLY_1_day.csv
# Data loaded: 253 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\TSLA_1_day.csv
# Stored data: 269 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\TSLA_1_day.csv
# Data loaded: 269 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\SPY_1_day.csv
# Stored data: 268 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\SPY_1_day.csv
# Data loaded: 268 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\XLY_1_day.csv
# Stored data: 253 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\XLY_1_day.csv
# Data loaded: 253 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\ROKU_1_day.csv
# Stored data: 504 rows of data
# Loading data from C:\Users\sidsu\anaconda3\envs\SB4\stockbot4\data\historical_data_store\ROKU_1_day.csv
# Data loaded: 504 rows of data
# Symbol SOFI did not pass the fundamentals

# %%
bot.tracker_df
# Out:
#   symbol  allowedETF  PBX_ALL_Scores
# 0   TSLA        True             NaN
# 1   ROKU        True             NaN
# 2   SOFI       False             NaN

# %%
bot.stocks['TSLA'].frames['1 day'].data.iloc[-1]
# Out:
# open                 423.87
# high                 427.93
# low                  402.54
# close                403.84
# volume            519174.00
#                     ...
# Stgy_PB_step1          0.00
# Stgy_PB_total          0.00
# PBX_BO_Score            NaN
# PBX_PB_Score            NaN
# PBX_ALL_Scores          NaN
# Name: 2024-12-31 00:00:00, Length: 69, dtype: float64

# %%
from STOCKBOT import StockBot
bot = StockBot()
bot.connect_to_ib()


# symbols = bot.scanner.scan_results_df['Symbol'].to_list()
# allowed_etfs = bot.ma.sector_report_filtered_list
symbols = ['TSLA', 'MSFT']
allowed_etfs = ['XLF', 'XLU', 'XLV']


bot.setup_stocks(symbols, allowed_etfs, includeDisallowedETFs=False)
# Out:
# Error 430, reqId 222: The fundamentals data for the security specified is not available.Not allowed, contract: Stock(symbol='TSLA', exchange='SMART', currency='USD')
# Error 430, reqId 224: The fundamentals data for the security specified is not available.Not allowed, contract: Stock(symbol='MSFT', exchange='SMART', currency='USD')

# %%
bot.stocks['TSLA'].fundamentals.req_fundamentals(max_days_old=1)
bot.stocks['TSLA'].fundamentals.get_funadmentals_validation_results(allowed_etfs)
# Out:
# Error 430, reqId 226: The fundamentals data for the security specified is not available.Not allowed, contract: Stock(symbol='TSLA', exchange='SMART', currency='USD')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 bot.stocks['TSLA'].fundamentals.req_fundamentals(max_days_old=1)
# ----> 2 bot.stocks['TSLA'].fundamentals.get_funadmentals_validation_results(allowed_etfs)
#
# File c:\Users\sidsu\anaconda3\envs\SB4\stockbot4\stock_fundamentals.py:528, in Fundamentals.get_funadmentals_validation_results(self, allowed_etfs)
#     526 def get_funadmentals_validation_results(self, allowed_etfs: List[str]) -> Dict:
#     527     return {
# --> 528         'Sector1 Valid': self.validate_fundamental('primary_etf', 'isin', allowed_etfs, description='Stocks primary sector ETF is allowed'),
#     529         # 'Sector2 Valid': self.validate_fundamental('secondary_etf', 'isin', allowed_etfs, description='Stocks primary sector ETF is allowed'),
#     530         'Market Cap > 300M': self.validate_fundamental('market_cap', '>=', 300, description='Market cap is greater than 300M'),
#     531         'Vol 10DayMA > 300K': self.validate_fundamental('volume_10day_avg', '>=', 0.3, description='Volume is greater than 300k'),
#     532         'Fundamentals Passed': self.validation_fundamentals_has_passed()
#     533     }
#
# File c:\Users\sidsu\anaconda3\envs\SB4\stockbot4\stock_fundamentals.py:409, in Fundamentals.validate_fundamental(self, key, validation_type, value, description)
#     397 """
#     398 Validates a fundamental value against a specified condition.
#     399
#    (...)
#     406     bool: True if validation passes, False otherwise
#     407 """
#     408 if self.fundamentals is None:
# --> 409     raise ValueError("Fundamentals data not initialized")
#     411 # Check if the fundamental exists
#     412 if not hasattr(self.fundamentals, key):
#
# ValueError: Fundamentals data not initialized

# %%
bot.disiconnect_from_ib()

# %%
def insert_tracker_data(df, whereColumn:str, whereValue:str, insertAtColumn:float, insertValue:float):
    df.loc[df[whereColumn] == whereValue, insertAtColumn] = insertValue
    return df

import pandas as pd
df = pd.DataFrame({
    'symbol': ['TSLA', 'ROKU', 'SOFI'],
    'allowedETF': [True, True, False]
})

insert_tracker_data(df, 'symbol', 'TSLA', 'bob', False)
insert_tracker_data(df, 'symbol', 'ROKU', 'bob', 20)
# Out:
#   symbol  allowedETF    bob
# 0   TSLA        True  False
# 1   ROKU        True     20
# 2   SOFI       False    NaN
