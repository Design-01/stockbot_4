# %%
from datetime import datetime, timedelta
from manager import MarketDataManager

# Initialize with example parameters
trade_start = datetime(2024, 10, 1)
trade_end = datetime(2024, 10, 5)

tesla_data = MarketDataManager(
    api_key = '171136ac7161454b8f4abeb987c72b02',
    symbol="TSLA",
    timeframes=[
        ("1min", "1day"),   # 1-minute candles for the past day
        ("2min", "1day"),   # 1-minute candles for the past day
        ("5min", "1day"),   # 5-minute candles for the past day
        ("10min", "1day"),   # 5-minute candles for the past day
        # ("15min", "3days"), # 15-minute candles for the past 3 days
        # ("1h", "5days")     # 1-hour candles for the past 5 days
    ],
    mode="hist", # Use "live" for real-time data or "hist" for historical data
    trade_start=trade_start, # if mode is"live" then this date must be now.
    trade_end=trade_end # if mode is "hist" then this date cannot be in the future
)
# Out:
# Loaded forward-looking data:
# Interval: 1min
# Bars: 390
# Period: 2024-10-01 00:00 to 2024-10-05 00:00
#
#
# ...
# Data Summary for TSLA (HIST mode)
# ...
#
# Historical Data:
# ----------------------------------------
#
# 1min Timeframe:
# ----------------------------------------
# Start Time: 2024-09-30 09:30
# End Time:   2024-09-30 15:59
# Bar Count:  390
# Lookback:   1day
# Coverage:   100.3% of expected bars
#
# 2min Timeframe:
# ----------------------------------------
# Start Time: 2024-09-30 09:30
# End Time:   2024-09-30 15:58
# Bar Count:  195
# Lookback:   1day
# Coverage:   100.5% of expected bars
#
# 5min Timeframe:
# ----------------------------------------
# Start Time: 2024-09-30 09:30
# End Time:   2024-09-30 15:55
# Bar Count:  78
# Lookback:   1day
# Coverage:   101.3% of expected bars
#
# 10min Timeframe:
# ----------------------------------------
# Start Time: 2024-09-30 09:30
# End Time:   2024-09-30 15:50
# Bar Count:  39
# Lookback:   1day
# ...

# %%
#!!! K E E P   R U N N I N G   T H I S   C E L L  T O   U P D A T E   D A T A !!!
tesla_data.update_timeframes()
display(tesla_data.get_data("1min", lookback=5))
display(tesla_data.get_data("5min", lookback=5))
# Out:
#                           open       high        low      close    volume
# 2024-10-01 11:02:00  252.96001  252.96001  252.96001  252.96001  147306.0
# 2024-10-01 11:03:00  253.15500  253.15500  253.15500  253.15500  139825.0
# 2024-10-01 11:04:00  252.85001  252.85001  252.85001  252.85001  154744.0
# 2024-10-01 11:05:00  252.36501  252.36501  252.36501  252.36501  320657.0
# 2024-10-01 11:06:00  252.35500  252.35500  252.35500  252.35500  332474.0
#                           open       high        low      close     volume
# 2024-10-01 10:45:00  251.50999  252.57100  251.50999  252.57100  1346925.0
# 2024-10-01 10:50:00  252.12500  252.95740  252.12500  252.87000  1295142.0
# 2024-10-01 10:55:00  253.39000  253.39000  252.84000  253.03900  1215146.0
# 2024-10-01 11:00:00  252.77650  253.15500  252.77650  252.85001   835135.0
# 2024-10-01 11:05:00  252.36501  252.36501  252.35500  252.35500   653131.0

# %%
from datetime import datetime, timedelta
from manager import MarketDataManager

# Initialize with example parameters
# start_date = datetime(2024, 10, 1)
start_date = datetime.now() 
# end_date = datetime(2024, 10, 25)
end_date = datetime.now()

tesla_data = MarketDataManager(
    api_key = '171136ac7161454b8f4abeb987c72b02',
    # symbol="TSLA",
    symbol="EUR/USD",
    timeframes=[
        ("1min", "1day"),   # 1-minute candles for the past day
        ("5min", "1day"),   # 5-minute candles for the past day
        ("15min", "3days"), # 15-minute candles for the past 3 days
        ("1h", "5days")     # 1-hour candles for the past 5 days
    ],
    mode="live", # Use "live" for real-time data or "hist" for historical data
    init_start_date=start_date, # if mode is"live" then this date must be now.
    init_end_date=end_date # if mode is "hist" then this date cannot be in the future
)
# Out:
# Error loading 1min data for EUR/USD: No data is available on the specified dates. Try setting different start/end dates.
# Error loading 5min data for EUR/USD: No data is available on the specified dates. Try setting different start/end dates.
# Error loading 15min data for EUR/USD: No data is available on the specified dates. Try setting different start/end dates.
# Error loading 1h data for EUR/USD: No data is available on the specified dates. Try setting different start/end dates.
#
# ...
# Data Summary for EUR/USD (LIVE mode)
# ...
#
# 1min Timeframe:
# ----------------------------------------
# Status: No data loaded
#
# 5min Timeframe:
# ----------------------------------------
# Status: No data loaded
#
# 15min Timeframe:
# ----------------------------------------
# Status: No data loaded
#
# 1h Timeframe:
# ----------------------------------------
# Status: No data loaded
#
# ...

# %%
tesla_data.run_live(iterations=3, show_messages=True, until=None)
# Out:
# ...
# Starting live data stream for EUR/USD
# Historical data loaded up to: 2024-10-26 08:10
# ...
#
# -----------------------
# --Websocket connected--
# -----------------------
# messages received:  0
# iteration: 1
# {'event': 'subscribe-status', 'status': 'warning', 'success': [{'symbol': 'EUR/USD', 'type': 'PHYSICAL_CURRENCY'}], 'fails': [{'symbol': 'USD'}]}
# messages received:  0
# iteration: 2
# {'event': 'heartbeat', 'status': 'ok'}
# messages received:  0
# iteration: 3
# {'event': 'heartbeat', 'status': 'ok'}
# ----------------------
# Websocket disconnected
# ----------------------

# %%
def get_next_lowest_interval(requested_interval):
    available_intervals = ['1min', '5min', '15min', '30min', '45min', '1h', '2h', '4h', '8h', '1day', '1week', '1month']
    interval_map = {
        '1min': 1, '5min': 5, '15min': 15, '30min': 30, '45min': 45,
        '1h': 60, '2h': 120, '4h': 240, '8h': 480,
        '1day': 1440, '1week': 10080, '1month': 43200
    }
    
    # Convert requested interval to minutes
    if 'min' in requested_interval:
        requested_minutes = int(requested_interval.replace('min', ''))
    elif 'h' in requested_interval:
        requested_minutes = int(requested_interval.replace('h', '')) * 60
    elif 'day' in requested_interval:
        requested_minutes = int(requested_interval.replace('day', '')) * 1440
    elif 'week' in requested_interval:
        requested_minutes = int(requested_interval.replace('week', '')) * 10080
    elif 'month' in requested_interval:
        requested_minutes = int(requested_interval.replace('month', '')) * 43200
    else:
        raise ValueError(f"Invalid interval: {requested_interval}")
    
    # Find all common denominators that are less than requested interval
    common_denominators = []
    for interval in available_intervals:
        interval_minutes = interval_map[interval]
        if interval_minutes <= requested_minutes and requested_minutes % interval_minutes == 0:
            common_denominators.append(interval)
    
    # If we found common denominators, return the highest one
    if common_denominators:
        return common_denominators[-1]
    
    # If no common denominators, find the highest interval that's less than requested
    valid_intervals = [interval for interval in available_intervals 
                      if interval_map[interval] < requested_minutes]
    return valid_intervals[-1] if valid_intervals else '1min'

# Test the function
print(get_next_lowest_interval('1min')) # 1min
print(get_next_lowest_interval('5min')) # 5min
print(get_next_lowest_interval('12min')) # 1min
print(get_next_lowest_interval('15min')) # 15min
print(get_next_lowest_interval('20min')) # 5min
print(get_next_lowest_interval('30min')) # 30min
# Out:
# 1min
# 5min
# 1min
# 15min
# 5min
# 30min
